# %%
import numpy as np
import pandas as pd
from os import chdir

# %%
chdir('/home/ecosystem/DePaul/CSC478/Week3')

# %%
vstable = pd.read_csv("video_store_3.csv", index_col=0, na_values=["?"])

vstable.shape
# Out:
# (50, 7)

# %%
vstable.head()
# Out:
#         Gender  Income  Age  Rentals  Avg Per Visit   Genre Incidentals
# Cust ID
# 1            M   45000   25       32            2.5  Action         Yes
# 2            F   54000   33       12            3.4   Drama          No
# 3            F   32000  NaN       42            1.6  Comedy          No
# 4          NaN   59000   70       16            4.2   Drama         Yes
# 5            M   37000   35       25            3.2  Action         Yes

# %%
vstable.describe(include="all")
# Out:
#        Gender        Income        Age    Rentals  Avg Per Visit  Genre  \
# count      45     50.000000  43.000000  50.000000      50.000000     50
# unique      2           NaN        NaN        NaN            NaN      3
# top         F           NaN        NaN        NaN            NaN  Drama
# freq       23           NaN        NaN        NaN            NaN     20
# mean      NaN  42300.000000  30.930233  26.320000       2.748000    NaN
# std       NaN  21409.753642  11.650455  10.047723       0.898125    NaN
# min       NaN   1000.000000  16.000000   9.000000       1.100000    NaN
# 25%       NaN  26750.000000  22.000000  19.000000       2.125000    NaN
# 50%       NaN  41000.000000  29.000000  25.000000       2.750000    NaN
# 75%       NaN  56750.000000  35.000000  32.000000       3.375000    NaN
# max       NaN  89000.000000  70.000000  48.000000       4.700000    NaN
#
#        Incidentals
# count           50
# unique           2
# top            Yes
# freq            26
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
vstable[vstable.Gender.isnull()]
# Out:
#         Gender  Income  Age  Rentals  Avg Per Visit   Genre Incidentals
# Cust ID
# 4          NaN   59000   70       16            4.2   Drama         Yes
# 9          NaN   38000   21       18            2.1  Comedy          No
# 15         NaN   68000   30       36            2.7  Comedy         Yes
# 25         NaN    1000   16       25            1.4  Comedy         Yes
# 33         NaN   23000   25       28            2.7  Action          No

# %%
vstable[vstable.Age.isnull()]
# Out:
#         Gender  Income  Age  Rentals  Avg Per Visit   Genre Incidentals
# Cust ID
# 3            F   32000  NaN       42            1.6  Comedy          No
# 7            F   29000  NaN       19            3.8   Drama          No
# 14           M   45000  NaN       24            2.7   Drama          No
# 23           F    2000  NaN       30            2.5  Comedy          No
# 31           F   49000  NaN       15            3.2  Comedy          No
# 41           F   50000  NaN       17            1.4   Drama          No
# 46           F   57000  NaN        9            1.1   Drama          No

# %%
age_mean = vstable.Age.mean()
vstable.Age.fillna(age_mean, axis=0, inplace=True)

# %%
vstable.dropna(axis=0, inplace=True)
vstable.shape
# Out:
# (45, 7)

# %%
vstable.head(10)
# Out:
#         Gender  Income        Age  Rentals  Avg Per Visit   Genre Incidentals
# Cust ID
# 1            M   45000  25.000000       32            2.5  Action         Yes
# 2            F   54000  33.000000       12            3.4   Drama          No
# 3            F   32000  30.930233       42            1.6  Comedy          No
# 5            M   37000  35.000000       25            3.2  Action         Yes
# 6            M   18000  20.000000       29            1.7  Action          No
# 7            F   29000  30.930233       19            3.8   Drama          No
# 8            M   74000  25.000000       31            2.4  Action         Yes
# 10           F   65000  40.000000       21            3.3   Drama          No
# 11           F   41000  22.000000       48            2.3   Drama         Yes
# 12           F   26000  22.000000       32            2.9  Action         Yes
